# %%
import requests
import json
from datetime import datetime

BASE_URL = "http://localhost:8000"

def test_api_comprehensive():
    print("🧪 Testing Weather Prediction API - Full Test Suite")
    print("=" * 60)
    
    # Test 1: Root endpoint
    print("\n1️⃣ Testing Root Endpoint")
    print("-" * 40)
    try:
        response = requests.get(f"{BASE_URL}/")
        print(f"Status Code: {response.status_code}")
        if response.status_code == 200:
            data = response.json()
            print(f"✅ SUCCESS - Project: {data.get('project', 'N/A')}")
            print(f"   Description: {data.get('description', 'N/A')}")
            print(f"   Available Endpoints: {len(data.get('endpoints', {}))}")
        else:
            print(f"❌ FAILED - Status: {response.status_code}")
            print(f"   Response: {response.text}")
    except Exception as e:
        print(f"❌ ERROR: {e}")
    
    # Test 2: Health endpoint
    print("\n2️⃣ Testing Health Endpoint")
    print("-" * 40)
    try:
        response = requests.get(f"{BASE_URL}/health/")
        print(f"Status Code: {response.status_code}")
        if response.status_code == 200:
            data = response.json()
            print(f"✅ SUCCESS - Health Status: {data}")
        else:
            print(f"❌ FAILED - Status: {response.status_code}")
            print(f"   Response: {response.text}")
    except Exception as e:
        print(f"❌ ERROR: {e}")
    
    # Test 3: API Documentation
    print("\n3️⃣ Testing API Documentation")
    print("-" * 40)
    try:
        response = requests.get(f"{BASE_URL}/docs")
        print(f"Status Code: {response.status_code}")
        if response.status_code == 200:
            print(f"✅ SUCCESS - API Documentation is accessible")
            print(f"   Content Length: {len(response.content)} bytes")
        else:
            print(f"❌ FAILED - Status: {response.status_code}")
    except Exception as e:
        print(f"❌ ERROR: {e}")
    
    # Test 4: Rain Prediction
    print("\n4️⃣ Testing Rain Prediction Endpoint")
    print("-" * 40)
    test_date = "2023-01-01"
    try:
        response = requests.get(f"{BASE_URL}/predict/rain/?date={test_date}")
        print(f"Status Code: {response.status_code}")
        if response.status_code == 200:
            data = response.json()
            print(f"✅ SUCCESS - Rain Prediction:")
            print(f"   Input Date: {data.get('input_date', 'N/A')}")
            prediction = data.get('prediction', {})
            print(f"   Prediction Date: {prediction.get('date', 'N/A')}")
            print(f"   Will Rain: {prediction.get('will_rain', 'N/A')}")
            print(f"   Full Response: {json.dumps(data, indent=2)}")
        else:
            print(f"❌ FAILED - Status: {response.status_code}")
            print(f"   Response: {response.text}")
    except Exception as e:
        print(f"❌ ERROR: {e}")
    
    # Test 5: Precipitation Prediction
    print("\n5️⃣ Testing Precipitation Prediction Endpoint")
    print("-" * 40)
    try:
        response = requests.get(f"{BASE_URL}/predict/precipitation/fall/?date={test_date}")
        print(f"Status Code: {response.status_code}")
        if response.status_code == 200:
            data = response.json()
            print(f"✅ SUCCESS - Precipitation Prediction:")
            print(f"   Input Date: {data.get('input_date', 'N/A')}")
            prediction = data.get('prediction', {})
            print(f"   Start Date: {prediction.get('start_date', 'N/A')}")
            print(f"   End Date: {prediction.get('end_date', 'N/A')}")
            print(f"   Precipitation Fall: {prediction.get('precipitation_fall', 'N/A')} mm")
            print(f"   Full Response: {json.dumps(data, indent=2)}")
        else:
            print(f"❌ FAILED - Status: {response.status_code}")
            print(f"   Response: {response.text}")
    except Exception as e:
        print(f"❌ ERROR: {e}")
    
    # Test 6: Multiple date tests
    print("\n6️⃣ Testing Multiple Dates")
    print("-" * 40)
    test_dates = ["2023-06-15", "2023-12-25", "2024-01-01"]
    
    for date in test_dates:
        print(f"\n   Testing Date: {date}")
        try:
            # Rain prediction
            rain_response = requests.get(f"{BASE_URL}/predict/rain/?date={date}")
            rain_status = "✅" if rain_response.status_code == 200 else "❌"
            print(f"   {rain_status} Rain Prediction: {rain_response.status_code}")
            
            # Precipitation prediction
            precip_response = requests.get(f"{BASE_URL}/predict/precipitation/fall/?date={date}")
            precip_status = "✅" if precip_response.status_code == 200 else "❌"
            print(f"   {precip_status} Precipitation Prediction: {precip_response.status_code}")
            
        except Exception as e:
            print(f"   ❌ Error testing {date}: {e}")
    
    # Test 7: Error handling (invalid date)
    print("\n7️⃣ Testing Error Handling")
    print("-" * 40)
    invalid_dates = ["invalid-date", "2023-13-01", "2023-02-30"]
    
    for invalid_date in invalid_dates:
        print(f"\n   Testing Invalid Date: {invalid_date}")
        try:
            response = requests.get(f"{BASE_URL}/predict/rain/?date={invalid_date}")
            if response.status_code == 422:
                print(f"   ✅ Proper error handling: {response.status_code}")
            else:
                print(f"   ⚠️  Unexpected status: {response.status_code}")
                print(f"   Response: {response.text[:100]}...")
        except Exception as e:
            print(f"   ❌ Error: {e}")
    
    print("\n" + "=" * 60)
    print("🏁 API Testing Complete!")

def quick_test():
    """Quick test for basic functionality"""
    print("🚀 Quick API Test")
    print("-" * 30)
    
    endpoints = [
        ("Root", f"{BASE_URL}/"),
        ("Health", f"{BASE_URL}/health/"),
        ("Rain Prediction", f"{BASE_URL}/predict/rain/?date=2023-01-01"),
        ("Precipitation", f"{BASE_URL}/predict/precipitation/fall/?date=2023-01-01")
    ]
    
    for name, url in endpoints:
        try:
            response = requests.get(url)
            status = "✅" if response.status_code == 200 else "❌"
            print(f"{status} {name}: {response.status_code}")
        except Exception as e:
            print(f"❌ {name}: ERROR - {e}")

if __name__ == "__main__":
    # Run comprehensive test
    test_api_comprehensive()
    
    # Uncomment for quick test only
    # quick_test()
# Out:
# 🧪 Testing Weather Prediction API - Full Test Suite
# ============================================================
#
# 1️⃣ Testing Root Endpoint
# ----------------------------------------
# Status Code: 200
# ✅ SUCCESS - Project: Weather Prediction API
#    Description: N/A
#    Available Endpoints: 4
#    GitHub Repo: https://github.com/Doombuoyz/ML_api
#
# 2️⃣ Testing Health Endpoint
# ----------------------------------------
# Status Code: 200
# ✅ SUCCESS - Health Status: {'status': 'healthy', 'message': 'Welcome to the Weather Prediction API! The service is running smoothly.', 'models_loaded': {'rain_model': True, 'precipitation_model': True}}
#
# 3️⃣ Testing API Documentation
# ----------------------------------------
# Status Code: 200
# ✅ SUCCESS - API Documentation is accessible
#    Content Length: 946 bytes
#
# 4️⃣ Testing Rain Prediction Endpoint
# ----------------------------------------
# Status Code: 200
# ✅ SUCCESS - Rain Prediction:
#    Input Date: 2023-01-01
#    Prediction Date: 2023-01-08
#    Will Rain: True
#    Full Response: {
#   "input_date": "2023-01-01",
#   "prediction": {
#     "date": "2023-01-08",
#     "will_rain": true
#   },
#   "input_parameters": {}
# }
#
# 5️⃣ Testing Precipitation Prediction Endpoint
# ----------------------------------------
# Status Code: 200
# ✅ SUCCESS - Precipitation Prediction:
#    Input Date: 2023-01-01
#    Start Date: 2023-01-02
#    End Date: 2023-01-04
#    Precipitation Fall: 4.9 mm
#    Full Response: {
#   "input_date": "2023-01-01",
#   "prediction": {
#     "start_date": "2023-01-02",
#     "end_date": "2023-01-04",
#     "precipitation_fall": "4.9"
#   },
#   "input_parameters": {}
# }
#
# 6️⃣ Testing Multiple Dates
# ----------------------------------------
#
#    Testing Date: 2023-06-15
# Status Code: 200
# ✅ SUCCESS - Rain Prediction:
#    Input Date: 2023-01-01
#    Prediction Date: 2023-01-08
#    Will Rain: True
#    Full Response: {
#   "input_date": "2023-01-01",
#   "prediction": {
#     "date": "2023-01-08",
#     "will_rain": true
#   },
#   "input_parameters": {}
# }
#
# 5️⃣ Testing Precipitation Prediction Endpoint
# ----------------------------------------
# Status Code: 200
# ✅ SUCCESS - Precipitation Prediction:
#    Input Date: 2023-01-01
#    Start Date: 2023-01-02
#    End Date: 2023-01-04
#    Precipitation Fall: 4.9 mm
#    Full Response: {
#   "input_date": "2023-01-01",
#   "prediction": {
#     "start_date": "2023-01-02",
#     "end_date": "2023-01-04",
#     "precipitation_fall": "4.9"
#   },
#   "input_parameters": {}
# }
#
# 6️⃣ Testing Multiple Dates
# ----------------------------------------
#
#    Testing Date: 2023-06-15
#    ✅ Rain Prediction: 200
#    ✅ Rain Prediction: 200
#    ✅ Precipitation Prediction: 200
#
#    Testing Date: 2023-12-25
#    ✅ Precipitation Prediction: 200
#
#    Testing Date: 2023-12-25
#    ✅ Rain Prediction: 200
#    ✅ Rain Prediction: 200
#    ✅ Precipitation Prediction: 200
#
#    Testing Date: 2024-01-01
#    ✅ Precipitation Prediction: 200
#
#    Testing Date: 2024-01-01
#    ✅ Rain Prediction: 200
#    ✅ Precipitation Prediction: 200
#
# 7️⃣ Testing Error Handling
# ----------------------------------------
#
#    Testing Invalid Date: invalid-date
#    ⚠️  Unexpected status: 400
#    Response: {"detail":"Invalid date format. Expected format: YYYY-MM-DD"}...
#
#    Testing Invalid Date: 2023-13-01
#    ⚠️  Unexpected status: 400
#    Response: {"detail":"Invalid date format. Expected format: YYYY-MM-DD"}...
#
#    Testing Invalid Date: 2023-02-30
#    ⚠️  Unexpected status: 400
#    Response: {"detail":"Invalid date format. Expected format: YYYY-MM-DD"}...
#
# ============================================================
# 🏁 API Testing Complete!
#    ✅ Rain Prediction: 200
#    ✅ Precipitation Prediction: 200
#
# 7️⃣ Testing Error Handling
# ----------------------------------------
#
#    Testing Invalid Date: invalid-date
#    ⚠️  Unexpected status: 400
#    Response: {"detail":"Invalid date format. Expected format: YYYY-MM-DD"}...
#
#    Testing Invalid Date: 2023-13-01
#    ⚠️  Unexpected status: 400
#    Response: {"detail":"Invalid date format. Expected format: YYYY-MM-DD"}...
#
#    Testing Invalid Date: 2023-02-30
#    ⚠️  Unexpected status: 400
#    Response: {"detail":"Invalid date format. Expected format: YYYY-MM-DD"}...
#
# ============================================================
# 🏁 API Testing Complete!
